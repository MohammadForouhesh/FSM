# %%
import os, sys, inspect

cmd_folder = os.path.realpath(
    os.path.dirname(
        os.path.abspath(os.path.split(inspect.getfile( inspect.currentframe() ))[0])))

if cmd_folder not in sys.path:
    sys.path.insert(0, cmd_folder)
    
from transitions import *
from transitions.extensions import GraphMachine
from IPython.display import Image, display, display_png

class Matter(object):
    def is_valid(self):
        return True
    
    def is_not_valid(self):
        return False
    
    def is_also_valid(self):
        return True
    
    # graph object is created by the machine
    def show_graph(self):
        self.graph.draw('state.png', prog='dot')
        display(Image('state.png'))

# %%
transitions = [
    { 'trigger': 'melt', 'source': 'solid', 'dest': 'liquid' },
    { 'trigger': 'evaporate', 'source': 'liquid', 'dest': 'gas', 'conditions':'is_valid' },
    { 'trigger': 'sublimate', 'source': 'solid', 'dest': 'gas', 'unless':'is_not_valid' },
    { 'trigger': 'ionize', 'source': 'gas', 'dest': 'plasma', 
      'conditions':['is_valid','is_also_valid'] }
]
states=['solid', 'liquid', 'gas', 'plasma']

model = Matter()
machine = GraphMachine(model=model, 
                         states=states, 
                         transitions=transitions, 
                         auto_transitions=False, 
                         initial='solid', 
                         title="Matter is Fun!",
                         show_conditions=True)
model.show_graph()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-f8284e1c9298> in <module>()
#      16                          title="Matter is Fun!",
#      17                          show_conditions=True)
# ---> 18 model.show_graph()
#
# <ipython-input-9-87fc58e9e360> in show_graph(self)
#      24     # graph object is created by the machine
#      25     def show_graph(self):
# ---> 26         self.graph.draw('state.png', prog='dot')
#      27         display(Image('state.png'))
#
# /home/maometto/anaconda3/lib/python3.5/site-packages/pygraphviz/agraph.py in draw(self, path, format, prog, args)
#    1472             fh = self._get_fh(path, 'w+b')
#    1473             fh.write(data)
# -> 1474             if is_string_like(path):
#    1475                 fh.close()
#    1476             d = None
#
# /home/maometto/anaconda3/lib/python3.5/site-packages/pygraphviz/agraph.py in _run_prog(self, prog, args)
#    1333         if len(errors) > 0:
#    1334             warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# -> 1335         return b"".join(data)
#    1336
#    1337     def layout(self, prog='neato', args=''):
#
# OSError: b'Warning: Could not load "/home/maometto/anaconda3/lib/graphviz/libgvplugin_pango.so.6" - file not found\nWarning: Could not load "/home/maometto/anaconda3/lib/graphviz/libgvplugin_pango.so.6" - file not found\nFormat: "png" not recognized. Use one of: canon cmap cmapx cmapx_np dot eps fig gv imap imap_np ismap pdf pic plain plain-ext png pov ps ps2 svg svgz tk vml vmlz xdot xdot1.2 xdot1.4\n'

# %%
model.melt()
model.show_graph()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-dee3e1c85a90> in <module>()
#       1 model.melt()
# ----> 2 model.show_graph()
#
# <ipython-input-5-87fc58e9e360> in show_graph(self)
#      24     # graph object is created by the machine
#      25     def show_graph(self):
# ---> 26         self.graph.draw('state.png', prog='dot')
#      27         display(Image('state.png'))
#
# /home/maometto/anaconda3/lib/python3.5/site-packages/pygraphviz/agraph.py in draw(self, path, format, prog, args)
#    1472             fh = self._get_fh(path, 'w+b')
#    1473             fh.write(data)
# -> 1474             if is_string_like(path):
#    1475                 fh.close()
#    1476             d = None
#
# /home/maometto/anaconda3/lib/python3.5/site-packages/pygraphviz/agraph.py in _run_prog(self, prog, args)
#    1333         if len(errors) > 0:
#    1334             warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# -> 1335         return b"".join(data)
#    1336
#    1337     def layout(self, prog='neato', args=''):
#
# OSError: b'Warning: Could not load "/home/maometto/anaconda3/lib/graphviz/libgvplugin_pango.so.6" - file not found\nWarning: Could not load "/home/maometto/anaconda3/lib/graphviz/libgvplugin_pango.so.6" - file not found\nFormat: "png" not recognized. Use one of: canon cmap cmapx cmapx_np dot eps fig gv imap imap_np ismap pdf pic plain plain-ext png pov ps ps2 svg svgz tk vml vmlz xdot xdot1.2 xdot1.4\n'

# %%
model.evaporate()
model.show_graph()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-78aae10d2883> in <module>()
#       1 model.evaporate()
# ----> 2 model.show_graph()
#
# <ipython-input-5-87fc58e9e360> in show_graph(self)
#      24     # graph object is created by the machine
#      25     def show_graph(self):
# ---> 26         self.graph.draw('state.png', prog='dot')
#      27         display(Image('state.png'))
#
# /home/maometto/anaconda3/lib/python3.5/site-packages/pygraphviz/agraph.py in draw(self, path, format, prog, args)
#    1472             fh = self._get_fh(path, 'w+b')
#    1473             fh.write(data)
# -> 1474             if is_string_like(path):
#    1475                 fh.close()
#    1476             d = None
#
# /home/maometto/anaconda3/lib/python3.5/site-packages/pygraphviz/agraph.py in _run_prog(self, prog, args)
#    1333         if len(errors) > 0:
#    1334             warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# -> 1335         return b"".join(data)
#    1336
#    1337     def layout(self, prog='neato', args=''):
#
# OSError: b'Warning: Could not load "/home/maometto/anaconda3/lib/graphviz/libgvplugin_pango.so.6" - file not found\nWarning: Could not load "/home/maometto/anaconda3/lib/graphviz/libgvplugin_pango.so.6" - file not found\nFormat: "png" not recognized. Use one of: canon cmap cmapx cmapx_np dot eps fig gv imap imap_np ismap pdf pic plain plain-ext png pov ps ps2 svg svgz tk vml vmlz xdot xdot1.2 xdot1.4\n'

# %%
model.ionize()
model.show_graph()

# %%
# multimodel test
model1 = Matter()
model2 = Matter()
machine = GraphMachine(model=[model1, model2], 
                       states=states, 
                       transitions=transitions, 
                       auto_transitions=False, 
                       initial='solid', 
                       title="Matter is Fun!",
                       show_conditions=True)
model1.melt()
model1.show_graph()

# %%
model2.sublimate()
model2.show_graph()
